# %%
# Be sure to have installed pandas_datareader in bash shell 
# If you receive error message, ModuleNotFoundError: No module named 'pandas_datareader',
# then you need to pip install pandas_datareader

# %%
import pandas_datareader
from pandas_datareader import data
import matplotlib.pyplot as plot
import pandas as pd
path = 'D:/stat_with_python/data/'

# %%
# Only get the adjusted close.
netflix = data.DataReader("NFLX", 
                       start='2009-1-1', 
                       end='2020-01-31', 
                       data_source='yahoo')['Adj Close']

nf = pd.DataFrame(netflix)
nf.to_csv(path+'netflix.csv')

# %%
# Read in saved data, this will be in pandas dataframe format
netflix = pd.read_csv(path+'netflix.csv')
netflix.head()
# Out:
#          Date  Adj Close
# 0  2008-12-31   4.270000
# 1  2009-01-02   4.267143
# 2  2009-01-05   4.562857
# 3  2009-01-06   4.705714
# 4  2009-01-07   4.672857

# %%
netflix.tail()
# Out:
#             Date   Adj Close
# 2785  2020-01-27  342.880005
# 2786  2020-01-28  348.519989
# 2787  2020-01-29  343.160004
# 2788  2020-01-30  347.739990
# 2789  2020-01-31  345.089996

# %%
# Set datetime
from datetime import datetime
netflix['Date'] = pd.to_datetime(netflix['Date'])

# %%
# Set index
netflix.set_index('Date', inplace = True)
netflix.head()
# Out:
#             Adj Close
# Date
# 2008-12-31   4.270000
# 2009-01-02   4.267143
# 2009-01-05   4.562857
# 2009-01-06   4.705714
# 2009-01-07   4.672857

# %%
# Take a look at various fonts, lines, styles for matplotlib
print(plot.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plot.style.use('fivethirtyeight')
netflix.plot(title='Netflix Adj. Closing Price', figsize=(10,5), color='red')
plot.show()

# %%
# Convert the adjusted closing prices to cumulative returns.

# Take percentage change of stock price of Netflix
returns = netflix.pct_change()

# Calculate the cumulative product
#  In cumulative product, the length of returned series is same as input series and every element is equal 
# to the product of current and all previous values.

plot.style.use('bmh')
((1 + returns).cumprod() - 1).plot(title='Netflix Cumulative Returns', figsize=(10,5), color='purple')

# %%
# Plot the returns, which is the percentage change in adjusted closing price

plot.style.use('tableau-colorblind10')
netflix.pct_change().plot(figsize=(10,5), color = 'green');

# %% [markdown]
# ### Getting Data Using API Key

# %%
# source:  https://github.com/RomelTorres/alpha_vantage
# source:  https://alpha-vantage.readthedocs.io/en/latest/
# You will need to obtain a free API key from Alpha Vantage by
# going to https://www.alphavantage.co/


# In bash shell, type command below: 

# pip install alpha_vantage

# %%
# Pull intraday data, example using Disney stock
# Time serie Anlysis : https://sanjayjsw05.medium.com/time-series-analysis-complete-tutorial-for-beginners-part-1-58523000a0a3
from alpha_vantage.timeseries import TimeSeries #https://www.alphavantage.co/
my_API_Key = " AE3I19E4RPGA1ABP"

# ts = TimeSeries(key='YOUR_API_KEY_HERE')
ts = TimeSeries(key='HFWBAPPJ4B2C968U')

# Get json object with the intraday data and another with  the call's metadata
# Use "DIS" for Disney or fill in a stock ticker of your choice
data, meta_data = ts.get_intraday('DIS')

# %%
# Take a look at data structure
data
# Out:
# {'2021-02-16 20:00:00': {'1. open': '185.3100',
#   '2. high': '185.4000',
#   '3. low': '185.0000',
#   '4. close': '185.0000',
#   '5. volume': '3244'},
#  '2021-02-16 19:45:00': {'1. open': '185.3101',
#   '2. high': '185.4000',
#   '3. low': '185.3100',
#   '4. close': '185.4000',
#   '5. volume': '2635'},
#  '2021-02-16 19:30:00': {'1. open': '185.5000',
#   '2. high': '185.5000',
#   '3. low': '185.2200',
#   '4. close': '185.3000',
#   '5. volume': '1813'},
#  '2021-02-16 19:15:00': {'1. open': '185.5600',
#   '2. high': '185.7000',
#   '3. low': '185.5100',
#   '4. close': '185.5600',
#   '5. volume': '1097'},
#  '2021-02-16 19:00:00': {'1. open': '185.7300',
#   '2. high': '186.0000',
#   '3. low': '185.7000',
#   '4. close': '185.7000',
#   '5. volume': '1576'},
#  '2021-02-16 18:45:00': {'1. open': '185.9500',
#   '2. high': '186.0500',
#   '3. low': '185.7000',
#   '4. close': '185.7200',
#   '5. volume': '1498'},
#  '2021-02-16 18:30:00': {'1. open': '185.7700',
#   '2. high': '185.7700',
#   '3. low': '185.7700',
#   '4. close': '185.7700',
#   '5. volume': '120'},
#  '2021-02-16 18:15:00': {'1. open': '185.7800',
#   '2. high': '186.0000',
#   '3. low': '185.7300',
#   '4. close': '186.0000',
#   '5. volume': '3802'},
#  '2021-02-16 18:00:00': {'1. open': '185.8600',
#   '2. high': '185.8600',
#   '3. low': '185.7900',
#   '4. close': '185.8000',
#   '5. volume': '3156'},
#  '2021-02-16 17:45:00': {'1. open': '185.9300',
#   '2. high': '185.9400',
#   '3. low': '185.8600',
#   '4. close': '185.9400',
#   '5. volume': '2031'},
#  '2021-02-16 17:15:00': {'1. open': '185.8500',
#   '2. high': '186.3500',
#   '3. low': '185.8500',
#   '4. close': '186.0000',
#   '5. volume': '33089'},
#  '2021-02-16 17:00:00': {'1. open': '185.9800',
#   '2. high': '186.1000',
#   '3. low': '185.8200',
#   '4. close': '186.1000',
#   '5. volume': '1089'},
#  '2021-02-16 16:45:00': {'1. open': '185.9800',
#   '2. high': '186.1000',
#   '3. low': '185.8900',
#   '4. close': '185.8900',
#   '5. volume': '3880'},
#  '2021-02-16 16:30:00': {'1. open': '185.9000',
#   '2. high': '186.0000',
#   '3. low': '185.8000',
#   '4. close': '185.9500',
#   '5. volume': '3648'},
#  '2021-02-16 16:15:00': {'1. open': '186.4000',
#   '2. high': '186.4800',
#   '3. low': '186.0000',
#   '4. close': '186.0000',
#   '5. volume': '312208'},
#  '2021-02-16 16:00:00': {'1. open': '185.9700',
#   '2. high': '186.4000',
#   '3. low': '185.7500',
#   '4. close': '186.3500',
#   '5. volume': '762385'},
#  '2021-02-16 15:45:00': {'1. open': '185.6200',
#   '2. high': '186.0750',
#   '3. low': '185.4840',
#   '4. close': '185.9625',
#   '5. volume': '267644'},
#  '2021-02-16 15:30:00': {'1. open': '185.2450',
#   '2. high': '185.6300',
#   '3. low': '185.2417',
#   '4. close': '185.6200',
#   '5. volume': '191929'},
#  '2021-02-16 15:15:00': {'1. open': '185.4850',
#   '2. high': '185.6256',
#   '3. low': '185.1900',
#   '4. close': '185.2450',
#   '5. volume': '199507'},
#  '2021-02-16 15:00:00': {'1. open': '185.7600',
#   '2. high': '185.9050',
#   '3. low': '185.2550',
#   '4. close': '185.4900',
#   '5. volume': '191763'},
#  '2021-02-16 14:45:00': {'1. open': '185.8140',
#   '2. high': '186.0490',
#   '3. low': '185.6407',
#   '4. close': '185.7600',
#   '5. volume': '144288'},
#  '2021-02-16 14:30:00': {'1. open': '185.3900',
#   '2. high': '185.8500',
#   '3. low': '185.3700',
#   '4. close': '185.8290',
#   '5. volume': '121272'},
#  '2021-02-16 14:15:00': {'1. open': '185.6100',
#   '2. high': '185.8300',
#   '3. low': '185.2284',
#   '4. close': '185.4200',
#   '5. volume': '267772'},
#  '2021-02-16 14:00:00': {'1. open': '185.8400',
#   '2. high': '186.0000',
#   '3. low': '185.5000',
#   '4. close': '185.6000',
#   '5. volume': '438242'},
#  '2021-02-16 13:45:00': {'1. open': '185.8400',
#   '2. high': '185.9900',
#   '3. low': '185.7400',
#   '4. close': '185.8500',
#   '5. volume': '197376'},
#  '2021-02-16 13:30:00': {'1. open': '185.7800',
#   '2. high': '185.8800',
#   '3. low': '185.6300',
#   '4. close': '185.8800',
#   '5. volume': '146786'},
#  '2021-02-16 13:15:00': {'1. open': '186.0500',
#   '2. high': '186.1862',
#   '3. low': '185.6949',
#   '4. close': '185.7600',
#   '5. volume': '137058'},
#  '2021-02-16 13:00:00': {'1. open': '185.6690',
#   '2. high': '186.2800',
#   '3. low': '185.5650',
#   '4. close': '186.0100',
#   '5. volume': '232255'},
#  '2021-02-16 12:45:00': {'1. open': '185.9240',
#   '2. high': '186.2700',
#   '3. low': '185.6800',
#   '4. close': '185.6900',
#   '5. volume': '247612'},
#  '2021-02-16 12:30:00': {'1. open': '185.4000',
#   '2. high': '186.1114',
#   '3. low': '185.2386',
#   '4. close': '185.9000',
#   '5. volume': '365425'},
#  '2021-02-16 12:15:00': {'1. open': '185.8600',
#   '2. high': '186.1000',
#   '3. low': '184.8600',
#   '4. close': '185.3800',
#   '5. volume': '508436'},
#  '2021-02-16 12:00:00': {'1. open': '186.2000',
#   '2. high': '186.2600',
#   '3. low': '185.6161',
#   '4. close': '185.9100',
#   '5. volume': '216402'},
#  '2021-02-16 11:45:00': {'1. open': '186.2600',
#   '2. high': '186.3680',
#   '3. low': '185.6000',
#   '4. close': '186.2240',
#   '5. volume': '365173'},
#  '2021-02-16 11:30:00': {'1. open': '186.1800',
#   '2. high': '186.2900',
#   '3. low': '185.8300',
#   '4. close': '186.2500',
#   '5. volume': '292505'},
#  '2021-02-16 11:15:00': {'1. open': '185.9600',
#   '2. high': '186.3500',
#   '3. low': '185.8700',
#   '4. close': '186.2100',
#   '5. volume': '437595'},
#  '2021-02-16 11:00:00': {'1. open': '186.8500',
#   '2. high': '186.8737',
#   '3. low': '185.7800',
#   '4. close': '185.9900',
#   '5. volume': '518730'},
#  '2021-02-16 10:45:00': {'1. open': '186.7200',
#   '2. high': '187.1300',
#   '3. low': '186.3008',
#   '4. close': '186.8200',
#   '5. volume': '339633'},
#  '2021-02-16 10:30:00': {'1. open': '185.6207',
#   '2. high': '186.8200',
#   '3. low': '185.5700',
#   '4. close': '186.6700',
#   '5. volume': '500917'},
#  '2021-02-16 10:15:00': {'1. open': '185.8650',
#   '2. high': '186.6400',
#   '3. low': '185.6101',
#   '4. close': '185.6900',
#   '5. volume': '497307'},
#  '2021-02-16 10:00:00': {'1. open': '187.0460',
#   '2. high': '187.7710',
#   '3. low': '185.5000',
#   '4. close': '185.8650',
#   '5. volume': '877806'},
#  '2021-02-16 09:45:00': {'1. open': '187.3000',
#   '2. high': '188.4400',
#   '3. low': '186.1000',
#   '4. close': '187.0500',
#   '5. volume': '1581607'},
#  '2021-02-16 09:30:00': {'1. open': '188.2300',
#   '2. high': '188.2500',
#   '3. low': '187.3700',
#   '4. close': '187.3700',
#   '5. volume': '30883'},
#  '2021-02-16 09:15:00': {'1. open': '188.6800',
#   '2. high': '188.7000',
#   '3. low': '188.2500',
#   '4. close': '188.2500',
#   '5. volume': '18140'},
#  '2021-02-16 09:00:00': {'1. open': '188.7300',
#   '2. high': '188.8000',
#   '3. low': '188.6700',
#   '4. close': '188.8000',
#   '5. volume': '11381'},
#  '2021-02-16 08:45:00': {'1. open': '188.9100',
#   '2. high': '189.0000',
#   '3. low': '187.6700',
#   '4. close': '188.8400',
#   '5. volume': '15265'},
#  '2021-02-16 08:30:00': {'1. open': '188.6199',
#   '2. high': '189.0000',
#   '3. low': '188.6000',
#   '4. close': '188.9999',
#   '5. volume': '8469'},
#  '2021-02-16 08:15:00': {'1. open': '189.2975',
#   '2. high': '189.3400',
#   '3. low': '188.5100',
#   '4. close': '188.6000',
#   '5. volume': '37671'},
#  '2021-02-16 08:00:00': {'1. open': '189.2300',
#   '2. high': '189.2400',
#   '3. low': '189.0000',
#   '4. close': '189.0300',
#   '5. volume': '7035'},
#  '2021-02-16 07:45:00': {'1. open': '189.2500',
#   '2. high': '189.2500',
#   '3. low': '189.2400',
#   '4. close': '189.2500',
#   '5. volume': '1435'},
#  '2021-02-16 07:30:00': {'1. open': '189.2200',
#   '2. high': '189.2500',
#   '3. low': '189.2200',
#   '4. close': '189.2500',
#   '5. volume': '4225'},
#  '2021-02-16 07:15:00': {'1. open': '189.2800',
#   '2. high': '189.2900',
#   '3. low': '189.0600',
#   '4. close': '189.2300',
#   '5. volume': '9575'},
#  '2021-02-16 06:45:00': {'1. open': '189.2500',
#   '2. high': '189.5000',
#   '3. low': '189.2100',
#   '4. close': '189.5000',
#   '5. volume': '4192'},
#  '2021-02-16 06:30:00': {'1. open': '188.8000',
#   '2. high': '188.9500',
#   '3. low': '188.8000',
#   '4. close': '188.9500',
#   '5. volume': '1699'},
#  '2021-02-16 05:45:00': {'1. open': '188.7400',
#   '2. high': '188.7400',
#   '3. low': '188.7400',
#   '4. close': '188.7400',
#   '5. volume': '199'},
#  '2021-02-16 04:45:00': {'1. open': '188.5100',
#   '2. high': '188.5100',
#   '3. low': '188.5100',
#   '4. close': '188.5100',
#   '5. volume': '1267'},
#  '2021-02-16 04:30:00': {'1. open': '189.1000',
#   '2. high': '189.1000',
#   '3. low': '189.0000',
#   '4. close': '189.0000',
#   '5. volume': '538'},
#  '2021-02-16 04:15:00': {'1. open': '189.2500',
#   '2. high': '189.2500',
#   '3. low': '189.2500',
#   '4. close': '189.2500',
#   '5. volume': '1069'},
#  '2021-02-12 20:00:00': {'1. open': '187.2500',
#   '2. high': '187.3000',
#   '3. low': '186.9000',
#   '4. close': '186.9000',
#   '5. volume': '10402'},
#  '2021-02-12 19:45:00': {'1. open': '187.3000',
#   '2. high': '187.3000',
#   '3. low': '187.2000',
#   '4. close': '187.3000',
#   '5. volume': '2713'},
#  '2021-02-12 19:30:00': {'1. open': '187.3499',
#   '2. high': '187.3499',
#   '3. low': '187.3000',
#   '4. close': '187.3000',
#   '5. volume': '344'},
#  '2021-02-12 19:15:00': {'1. open': '187.4000',
#   '2. high': '187.4400',
#   '3. low': '187.2000',
#   '4. close': '187.2000',
#   '5. volume': '3020'},
#  '2021-02-12 19:00:00': {'1. open': '187.2999',
#   '2. high': '187.4500',
#   '3. low': '187.2999',
#   '4. close': '187.4500',
#   '5. volume': '4010'},
#  '2021-02-12 18:45:00': {'1. open': '187.2000',
#   '2. high': '187.2500',
#   '3. low': '187.2000',
#   '4. close': '187.2300',
#   '5. volume': '5315'},
#  '2021-02-12 18:30:00': {'1. open': '187.3400',
#   '2. high': '187.3500',
#   '3. low': '187.2000',
#   '4. close': '187.2000',
#   '5. volume': '4495'},
#  '2021-02-12 18:15:00': {'1. open': '187.4000',
#   '2. high': '187.4000',
#   '3. low': '187.3000',
#   '4. close': '187.3000',
#   '5. volume': '3927'},
#  '2021-02-12 18:00:00': {'1. open': '187.4800',
#   '2. high': '187.4800',
#   '3. low': '187.4000',
#   '4. close': '187.4000',
#   '5. volume': '1294'},
#  '2021-02-12 17:45:00': {'1. open': '187.4500',
#   '2. high': '187.5000',
#   '3. low': '187.4000',
#   '4. close': '187.4000',
#   '5. volume': '4293'},
#  '2021-02-12 17:30:00': {'1. open': '187.4600',
#   '2. high': '187.4900',
#   '3. low': '187.4000',
#   '4. close': '187.4900',
#   '5. volume': '1886'},
#  '2021-02-12 17:15:00': {'1. open': '187.5000',
#   '2. high': '187.5500',
#   '3. low': '187.5000',
#   '4. close': '187.5000',
#   '5. volume': '6609'},
#  '2021-02-12 17:00:00': {'1. open': '187.4900',
#   '2. high': '187.6700',
#   '3. low': '187.4500',
#   '4. close': '187.4600',
#   '5. volume': '48961'},
#  '2021-02-12 16:45:00': {'1. open': '187.4600',
#   '2. high': '187.6700',
#   '3. low': '187.4000',
#   '4. close': '187.5000',
#   '5. volume': '8154'},
#  '2021-02-12 16:30:00': {'1. open': '187.4500',
#   '2. high': '187.4700',
#   '3. low': '187.4000',
#   '4. close': '187.4700',
#   '5. volume': '14795'},
#  '2021-02-12 16:15:00': {'1. open': '188.0500',
#   '2. high': '188.0500',
#   '3. low': '187.4500',
#   '4. close': '187.5000',
#   '5. volume': '93077'},
#  '2021-02-12 16:00:00': {'1. open': '187.9600',
#   '2. high': '188.1100',
#   '3. low': '187.3201',
#   '4. close': '187.6900',
#   '5. volume': '1358489'},
#  '2021-02-12 15:45:00': {'1. open': '187.5700',
#   '2. high': '188.1500',
#   '3. low': '187.5500',
#   '4. close': '187.9600',
#   '5. volume': '671105'},
#  '2021-02-12 15:30:00': {'1. open': '187.1900',
#   '2. high': '187.7600',
#   '3. low': '187.0600',
#   '4. close': '187.5900',
#   '5. volume': '425345'},
#  '2021-02-12 15:15:00': {'1. open': '187.7696',
#   '2. high': '188.0000',
#   '3. low': '187.0800',
#   '4. close': '187.1900',
#   '5. volume': '366052'},
#  '2021-02-12 15:00:00': {'1. open': '187.4500',
#   '2. high': '188.0500',
#   '3. low': '187.2800',
#   '4. close': '187.7352',
#   '5. volume': '380026'},
#  '2021-02-12 14:45:00': {'1. open': '187.5300',
#   '2. high': '187.6694',
#   '3. low': '187.2944',
#   '4. close': '187.4460',
#   '5. volume': '299425'},
#  '2021-02-12 14:30:00': {'1. open': '187.4100',
#   '2. high': '187.7057',
#   '3. low': '187.2700',
#   '4. close': '187.5600',
#   '5. volume': '363045'},
#  '2021-02-12 14:15:00': {'1. open': '187.7300',
#   '2. high': '187.7900',
#   '3. low': '187.3100',
#   '4. close': '187.4150',
#   '5. volume': '393843'},
#  '2021-02-12 14:00:00': {'1. open': '188.1312',
#   '2. high': '188.4000',
#   '3. low': '187.6000',
#   '4. close': '187.7200',
#   '5. volume': '440595'},
#  '2021-02-12 13:45:00': {'1. open': '188.2500',
#   '2. high': '188.8300',
#   '3. low': '188.0000',
#   '4. close': '188.1400',
#   '5. volume': '603824'},
#  '2021-02-12 13:30:00': {'1. open': '187.6350',
#   '2. high': '188.4500',
#   '3. low': '187.3700',
#   '4. close': '188.3000',
#   '5. volume': '678185'},
#  '2021-02-12 13:15:00': {'1. open': '188.2300',
#   '2. high': '188.5794',
#   '3. low': '187.3500',
#   '4. close': '187.6600',
#   '5. volume': '825943'},
#  '2021-02-12 13:00:00': {'1. open': '188.8148',
#   '2. high': '189.0500',
#   '3. low': '187.8100',
#   '4. close': '188.2200',
#   '5. volume': '847043'},
#  '2021-02-12 12:45:00': {'1. open': '189.0600',
#   '2. high': '189.1600',
#   '3. low': '188.3631',
#   '4. close': '188.8300',
#   '5. volume': '1068126'},
#  '2021-02-12 12:30:00': {'1. open': '189.5700',
#   '2. high': '190.0400',
#   '3. low': '189.0000',
#   '4. close': '189.0400',
#   '5. volume': '950891'},
#  '2021-02-12 12:15:00': {'1. open': '189.8150',
#   '2. high': '190.0300',
#   '3. low': '188.9400',
#   '4. close': '189.5900',
#   '5. volume': '963944'},
#  '2021-02-12 12:00:00': {'1. open': '189.2259',
#   '2. high': '189.9700',
#   '3. low': '189.1500',
#   '4. close': '189.7961',
#   '5. volume': '585621'},
#  '2021-02-12 11:45:00': {'1. open': '188.7400',
#   '2. high': '189.4900',
#   '3. low': '188.5000',
#   '4. close': '189.2700',
#   '5. volume': '656759'},
#  '2021-02-12 11:30:00': {'1. open': '188.8000',
#   '2. high': '189.2300',
#   '3. low': '188.4200',
#   '4. close': '188.7150',
#   '5. volume': '470509'},
#  '2021-02-12 11:15:00': {'1. open': '188.2900',
#   '2. high': '188.8900',
#   '3. low': '187.8700',
#   '4. close': '188.7800',
#   '5. volume': '776277'},
#  '2021-02-12 11:00:00': {'1. open': '189.2195',
#   '2. high': '189.4500',
#   '3. low': '187.6500',
#   '4. close': '188.2900',
#   '5. volume': '654773'},
#  '2021-02-12 10:45:00': {'1. open': '188.0900',
#   '2. high': '189.9800',
#   '3. low': '187.6200',
#   '4. close': '189.1200',
#   '5. volume': '1488198'},
#  '2021-02-12 10:30:00': {'1. open': '187.8400',
#   '2. high': '188.5497',
#   '3. low': '187.5155',
#   '4. close': '188.0700',
#   '5. volume': '1322320'},
#  '2021-02-12 10:15:00': {'1. open': '187.7950',
#   '2. high': '188.4900',
#   '3. low': '186.9000',
#   '4. close': '187.8550',
#   '5. volume': '1884941'},
#  '2021-02-12 10:00:00': {'1. open': '187.5600',
#   '2. high': '188.4800',
#   '3. low': '186.5600',
#   '4. close': '187.8000',
#   '5. volume': '2680967'},
#  '2021-02-12 09:45:00': {'1. open': '193.0000',
#   '2. high': '193.8500',
#   '3. low': '186.6601',
#   '4. close': '187.6754',
#   '5. volume': '4837619'},
#  '2021-02-12 09:30:00': {'1. open': '193.0000',
#   '2. high': '193.5000',
#   '3. low': '192.6500',
#   '4. close': '193.2300',
#   '5. volume': '87790'}}

# %%
# Reformat data
# The data frame structure is given by the call on alpha vantage rest API. 
# The column names of the data frames are the ones given by their data structure.

from alpha_vantage.timeseries import TimeSeries
from pprint import pprint

# ts = TimeSeries(key='YOUR_API_KEY_HERE', output_format='pandas')
ts = TimeSeries(key='HFWBAPPJ4B2C968U', output_format='pandas')

# Use 'DIS' for Disney
data, meta_data = ts.get_intraday(symbol='DIS',interval='1min', outputsize='full')
pprint(data.head(10))
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2021-02-16 20:00:00   185.05   185.05  185.00    185.00      813.0
# 2021-02-16 19:59:00   185.21   185.21  185.21    185.21      167.0
# 2021-02-16 19:58:00   185.30   185.30  185.30    185.30      320.0
# 2021-02-16 19:57:00   185.21   185.21  185.21    185.21      226.0
# 2021-02-16 19:53:00   185.40   185.40  185.40    185.40      690.0
# 2021-02-16 19:52:00   185.25   185.25  185.25    185.25      500.0
# 2021-02-16 19:51:00   185.31   185.31  185.31    185.31      528.0
# 2021-02-16 19:42:00   185.40   185.40  185.40    185.40      501.0
# 2021-02-16 19:39:00   185.31   185.31  185.31    185.31      130.0
# 2021-02-16 19:37:00   185.40   185.40  185.40    185.40     1001.0

# %%
# We can also plot crypto currencies prices like Bitcoin

from alpha_vantage.cryptocurrencies import CryptoCurrencies

cc = CryptoCurrencies(key='HFWBAPPJ4B2C968U', output_format='pandas')

data, meta_data = cc.get_digital_currency_daily(symbol='BTC', market='CNY')

# %%
# Plot the data

plot.style.use('dark_background')
data['4b. close (USD)'].plot(figsize=(10,5), linewidth=4, color='orange')
plot.tight_layout()
plot.title('Daily Close Value for Bitcoin (BTC)')
plot.grid()
plot.show()

# %% [markdown]
# ## Getting Data by Downloading a File

# %%
# Google Trends website, search terms "Golf", "Soccer", "Tennis", "Hockey", and "Baseball"
# Dates:  2004-01 to 2019-11
# Source:  https://trends.google.com/trends/explore?date=all&geo=US&q=Golf,Soccer,Tennis,Hockey,Baseball

# Click on down arrow to download csv file
# Save As "file name here" and choose location to save file
# Open up csv file and take a look at header format of data, column headings, missing values, and number of data

# %%
# Read in file
sports = pd.read_csv(path+"sports.csv", skiprows=2)

# %%
sports.head()
# Out:
#      Month  Golf: (United States)  Soccer: (United States)  \
# 0  2004-01                     45                       21
# 1  2004-02                     50                       24
# 2  2004-03                     63                       27
# 3  2004-04                     80                       29
# 4  2004-05                     82                       31
#
#    Tennis: (United States)  Hockey: (United States)  Baseball: (United States)
# 0                       13                       22                         24
# 1                       13                       23                         32
# 2                       15                       23                         45
# 3                       16                       16                         53
# 4                       17                       14                         52

# %%
# Reset column names
col_names = ['Month', 'Golf', 'Soccer', 'Tennis', 'Hockey', 'Baseball']

sports.columns = col_names

# %%
# verify column names have changed
sports.tail()
# Out:
#        Month  Golf  Soccer  Tennis  Hockey  Baseball
# 186  2019-07    58      42      17       6        35
# 187  2019-08    53      25      21       7        29
# 188  2019-09    39      31      21      10        25
# 189  2019-10    31      28      10      14        30
# 190  2019-11    27      27       9      16        17

# %%
# check for missing values
sports.isna().sum()
# Out:
# Month       0
# Golf        0
# Soccer      0
# Tennis      0
# Hockey      0
# Baseball    0
# dtype: int64

# %%
# Set index
sports.set_index('Month', inplace=True)

# %%
# Obtain the descriptive statistics
sports.describe()
# Out:
#              Golf      Soccer      Tennis      Hockey    Baseball
# count  191.000000  191.000000  191.000000  191.000000  191.000000
# mean    49.387435   28.853403   13.502618   14.879581   34.183246
# std     18.247326    8.682073    4.067683    5.916182   14.037279
# min     23.000000   17.000000    7.000000    6.000000   13.000000
# 25%     34.000000   24.000000   11.000000   11.000000   23.500000
# 50%     48.000000   28.000000   13.000000   15.000000   30.000000
# 75%     59.000000   32.000000   16.000000   18.000000   48.500000
# max    100.000000   84.000000   26.000000   55.000000   61.000000

# %%
# Plot the multi-time series
plot.style.use('classic')
sports.plot(figsize=(12,6), fontsize=10, linewidth=4)
plot.show();

# %%
# end
